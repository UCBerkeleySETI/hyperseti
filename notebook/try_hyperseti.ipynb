# %%
import test_hyperseti

import logging
logger_name = 'hyperseti'
logger = logging.getLogger(logger_name)
#logger.setLevel(logging.INFO)
logger.setLevel(logging.CRITICAL)
# Out:
# blosc filter already loaded, skip it.

# %%
# %matplotlib inline

# %%
test_hyperseti.test_dedoppler()
# Out:
# Inserted drift rate:  0.0 Hz / s 	SUM: 2030.53
# Recovered drift rate: -0.03125 Hz / s 	SUM: 2030.53
#
# Inserted drift rate:  0.1 Hz / s 	SUM: 1666.82
# Recovered drift rate: 0.125 Hz / s 	SUM: 1598.48
#
# Inserted drift rate:  0.5 Hz / s 	SUM: 1537.92
# Recovered drift rate: 0.53125 Hz / s 	SUM: 1530.38
#
# Inserted drift rate:  -0.25 Hz / s 	SUM: 1623.73
# Recovered drift rate: -0.28125 Hz / s 	SUM: 1459.63
#
# Inserted drift rate:  -0.5 Hz / s 	SUM: 1538.72
# Recovered drift rate: -0.5 Hz / s 	SUM: 1535.42

# %%
test_hyperseti.test_dedoppler_boxcar()
# Out:
# Total power in frame: 320.0
# MAXHOLD recovered power: 160.0
# dedopp recovered power (boxcar 1): 160.0
# dedopp recovered power (boxcar 2): 320.0

# %%
test_hyperseti.test_hitsearch()
# Out:
# --- Run dedoppler() then hitsearch() ---
#    driftrate      f_start      snr  driftrate_idx  channel_idx  boxcar_size
# 0        0.0  1000.002056  32000.0             32         2056           16
# --- run_pipeline with w/o merge ---
#    driftrate      f_start          snr  driftrate_idx  channel_idx  \
# 0    0.00000  1000.002056   353.553406             32         2056
# 1    0.00000  1000.002056   500.000000             32         2056
# 2    0.00000  1000.002056   707.106812             32         2056
# 3    0.00000  1000.002056  1000.000000             32         2056
# 4    0.00000  1000.002056  1414.213623             32         2056
# 5    0.15625  1000.002048  1000.319092             37         2048
# 6    0.18750  1000.002032   706.975403             38         2032
# 7   -0.65625  1000.002064   706.868347             11         2064
#
#    boxcar_size
# 0            1
# 1            2
# 2            4
# 3            8
# 4           16
# 5           32
# 6           64
# ...

# %%
test_hyperseti.test_hitsearch_multi()
# Out:
#     driftrate      f_start          snr  driftrate_idx  channel_idx  \
# 18   0.497457  6095.216242  1092.342773          313.0        501.0
# 19  -0.397009  6095.217078  1077.949341          126.0        800.0
# 8    0.071749  6095.223227   187.690903          224.0       3001.0
# 3    0.353960  6095.216309   127.214897          283.0        525.0
# 9    0.009566  6095.220564   112.748253          211.0       2048.0
# 4    0.693571  6095.216144   104.300735          354.0        466.0
# 5    0.291778  6095.216340   103.820114          270.0        536.0
# 10  -0.129148  6095.216938   103.560425          182.0        750.0
# 11   0.784452  6095.216097   103.377274          373.0        449.0
# 12  -0.669654  6095.217220   102.247719           69.0        851.0
#
#     boxcar_size
# 18          8.0
# 19          8.0
# 8           2.0
# 3           1.0
# 9           2.0
# 4           1.0
# 5           1.0
# 10          2.0
# 11          2.0
# 12          2.0
