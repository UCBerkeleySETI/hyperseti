# %%
import test_hyperseti
# Out:
# blosc filter already loaded, skip it.

# %%
# %matplotlib inline

# %%
test_hyperseti.test_dedoppler()
# Out:
# Inserted drift rate:  0.0 Hz / s 	SUM: 2034.44
# Recovered drift rate: -0.03125 Hz / s 	SUM: 2034.44
#
# Inserted drift rate:  0.1 Hz / s 	SUM: 1667.73
# Recovered drift rate: 0.125 Hz / s 	SUM: 1597.00
#
# Inserted drift rate:  0.5 Hz / s 	SUM: 1536.55
# Recovered drift rate: 0.5 Hz / s 	SUM: 1531.29
#
# Inserted drift rate:  -0.25 Hz / s 	SUM: 1622.69
# Recovered drift rate: -0.28125 Hz / s 	SUM: 1459.99
#
# Inserted drift rate:  -0.5 Hz / s 	SUM: 1537.96
# Recovered drift rate: -0.5 Hz / s 	SUM: 1530.93

# %%
test_hyperseti.test_dedoppler_boxcar()
# Out:
# Total power in frame: 320.0
# MAXHOLD recovered power: 160.0
# dedopp recovered power (boxcar 1): 160.0
# dedopp recovered power (boxcar 2): 320.0

# %%
test_hyperseti.test_hitsearch()
# Out:
# --- Run dedoppler() then hitsearch() ---
#    driftrate      f_start      snr  driftrate_idx  channel_idx  boxcar_size
# 0        0.0  1000.002056  32000.0             32         2056           16
# --- run_pipeline with w/o merge ---
#    driftrate      f_start          snr  driftrate_idx  channel_idx  \
# 0     0.0000  1000.002056   353.553406             32         2056
# 1     0.0000  1000.002056   500.000000             32         2056
# 2     0.0000  1000.002056   707.106812             32         2056
# 3     0.0000  1000.002056  1000.000000             32         2056
# 4     0.0000  1000.002056  1414.213623             32         2056
# 5     0.0625  1000.002059  1000.244812             34         2059
# 6    -0.0625  1000.002080   707.040100             30         2080
# 7    -0.6875  1000.002061   706.636719             10         2061
#
#    boxcar_size
# 0            1
# 1            2
# 2            4
# 3            8
# 4           16
# 5           32
# 6           64
# 7           64
# --- run merge_hits ---
#    driftrate      f_start          snr  driftrate_idx  channel_idx  \
# 4        0.0  1000.002056  1414.213623           32.0       2056.0
#
#    boxcar_size
# 4         16.0
# --- run_pipeline with merge ---
#    driftrate      f_start          snr  driftrate_idx  channel_idx  \
# 4        0.0  1000.002056  1414.213623           32.0       2056.0
#
#    boxcar_size
# 4         16.0

# %%
test_hyperseti.test_hitsearch_multi()
# Out:
#     driftrate      f_start          snr  driftrate_idx  channel_idx  \
# 18   0.497457  6095.216242  1099.019897          313.0        501.0
# 19  -0.397009  6095.217078  1081.655273          126.0        800.0
# 9    0.071749  6095.223227   188.538773          224.0       3001.0
# 3   -0.540507  6095.217139   138.096313           96.0        822.0
# 17   0.009566  6095.220564   118.800446          211.0       2048.0
# 11  -0.138714  6095.216949   111.459381          180.0        754.0
# 4    0.325261  6095.216326   107.487679          277.0        531.0
# 12   0.784452  6095.216102   107.110825          373.0        451.0
# 5   -0.215246  6095.216983   104.204208          164.0        766.0
# 6    0.291778  6095.216337   103.096474          270.0        535.0
#
#     boxcar_size
# 18          8.0
# 19          8.0
# 9           2.0
# 3           1.0
# 17          4.0
# 11          2.0
# 4           1.0
# 12          2.0
# 5           1.0
# 6           1.0
